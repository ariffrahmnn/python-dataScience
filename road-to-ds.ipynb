# %% [markdown]
# <a href="https://colab.research.google.com/github/ariffrahmnn/python-dataScience/blob/main/road-to-ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Heldo Worls")
# Out:
# Heldo Worls

# %%
list = [2, 3, 5, 6]
list[0] = 1
print(list)
# Out:
# [1, 3, 5, 6]

# %%
list = [2, 3, 4, 5, "Arif", ["hallo", 2, 3]]
print(len(list))
# Out:
# 6

# %%
list[-4]
# Out:
# 4

# %%
list2 = [1, 2, 3, 4, 5]
list3 = [3, 4, 5, 6, 7]
list2 + list3
# Out:
# [1, 2, 3, 4, 5, 3, 4, 5, 6, 7]

# %%
list3 = [1, 2, 3]
print(1 in list3)
print(4 in list3)
print(2 in list3)
# Out:
# True
# False
# True

# %%
nama_kotor = ["  Arif", "ikhsan  ", "  aMinah  "]
hasil_akhir_nama = []
for nama in nama_kotor:
  nama = nama.strip()
  nama = nama.lower()
  nama = nama.capitalize()
  hasil_akhir_nama.append(nama)
print(hasil_akhir_nama)
# Out:
# ['Arif', 'Ikhsan', 'Aminah']

# %%
nama_kotor2 = ["  Arif", "ikhsan  ", "  aMinah  "]
nama_bersih = [nama.strip().capitalize() for nama in nama_kotor2]
print(nama_bersih)
# Out:
# ['Arif', 'Ikhsan', 'Aminah']

# %%
data_angka = [12, 55, 60, 45, 80, 23, 100]
data_filter = [data for data in data_angka if data > 50 and data % 2 == 0]
print(data_filter)
# Out:
# [60, 80, 100]

# %%
dict_nama = {
    "nama": "Arif Rahman Muda",
    "umur": 21,
    "Genre": "Lofi"
}
dict_nama.update({
    "nama": "Arawinda Vyncia Derifson",
    "umur": "2 Tahun",
    "status": "Anak Kandung"
})
print(dict_nama["nama"])
print(dict_nama["umur"])
print(dict_nama["status"])
# Out:
# Arawinda Vyncia Derifson
# 2 Tahun
# Anak Kandung

# %%
data_angka = [12, 55, 60, 45, 80, 23, 100]
data_angka.extend([20, 30])
print(data_angka)
# Out:
# [12, 55, 60, 45, 80, 23, 100, 20, 30]

# %%
data_angka = [12, 44, 22, 99]

data_angka.sort(reverse=True)
print(data_angka)
# Out:
# [99, 44, 22, 12]

# %% [markdown]
# #### Description
# Split the string input_str = 'Kumar_Ravi_003' to the person's second name, first name and unique customer code. In this example, second_name= 'Kumar', first_name= 'Ravi', customer_code = '003'.
#
# A sample output of the input 'Kumar_Ravi_003' is:

# %%
input_str = "Kumar_Ravi_003"

# %%
input_str[0:5]
# Out:
# 'Kumar'

# %%
input_str[6:10]
# Out:
# 'Ravi'

# %%
input_str[11:]
# Out:
# '003'

# %%
print(input_str[0:5])
print(input_str[6:10])
print(input_str[11:])
# Out:
# Kumar
# Ravi
# 003

# %%
input_str.split("_")
# Out:
# ['Kumar', 'Ravi', '003']

# %%
suppose_list = [2, 33, 222, 14, 25]
suppose_list[:] = [12]
print(suppose_list)
# Out:
# [12]

# %%
L = ['one', 'two', 'three', 'four', 'five', 'six']
print(sorted(L))
print(L)
# Out:
# ['five', 'four', 'one', 'six', 'three', 'two']
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
list1 = ['SAS', 'R', 'PYTHON', 'SPSS']
list1[3] = 'Spark'
print(list1)
# Out:
# ['SAS', 'R', 'PYTHON', 'Spark']

# %%
list1 = ['SAS', 'R', 'PYTHON', 'SPSS']
del(list1[3])
list1.append('Spark')
print(list1)
# Out:
# ['SAS', 'R', 'PYTHON', 'Spark']

# %%
list1 = ['SAS', 'R', 'PYTHON', 'SPSS']
list1[0] = 'SPARK'
list1.extend(['TABLEU', 'EXCEL'])
print(list1)
# Out:
# ['SPARK', 'R', 'PYTHON', 'SPSS', 'TABLEU', 'EXCEL']

# %%
#Latihan Menghilangkan Spasi berlebih di dalam senuah Array
data_kodepos = [" 28291", "28123 ", " 21345 ", "28991"]
data_bersih = [teks.strip() for teks in data_kodepos]
print(data_bersih)
# Out:
# ['28291', '28123', '21345', '28991']

# %%
#Cari lima angka random lalu urutkan
angka_acak = [45, 12, 89, 7, 34, 23, 56, 99, 1]
lima_angka = angka_acak[0:5]
lima_angka.sort()
print(lima_angka)
# Out:
# [7, 12, 34, 45, 89]

# %%
#Percobaan mengganti isi dalam sebuah array
list_x = [10, 20, 30]
list_y = list_x

list_x[:] = [99]
print(list_y)
# Out:
# [99]

# %%
tup = (1, 2, 3, 4, 5)
print(tup)
# Out:
# (1, 2, 3, 4, 5)

# %%
tup2 = (1,3,4,5,6,1)
print(len(tup))
print(tup2)
# Out:
# 5
# (1, 3, 4, 5, 6, 1)

# %%
tuple = ('hello', 1,3)
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
import pandas as pd

df = pd.read_csv("Data.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3710/3197755531.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("Data.csv")
#       4
#       5 df.head()
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Pandas bakal otomatis ngelewati baris yang eror/rusak
df = pd.read_csv("data.csv", on_bad_lines='skip')
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                                    Centre de santé;"Genre (Gender)";"Âge (Age)";"Poids (Weight)";"Circonference du bras (Mua circumference)";"Haute température.(temperature  \
# CMA de DO;"Femme";"18";"55";"";"OUI";"OUI";"OUI...                                      84";"195";"11
# CMA de DO;"Homme";"26";"120";"";"OUI";"OUI";"OU...                                                NaN
# CMA de DO;"Homme";"25";"63";"";"OUI";"OUI";"OUI...                                                NaN
# CMA de DO;"Homme";"8";"24";"";"OUI";"OUI";"NON"...                           42";"NON";"NON";"NON";"7
# CMA de DO;"Homme";"6";"";"";"OUI";"OUI";"NON";"...                                                NaN
#
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_3710/1572743936.py in <cell line: 0>()
#       1 from google.colab import sheets
# ----> 2 sheet = sheets.InteractiveSheet(df=df)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/sheets.py in __init__(self, title, url, sheet_id, df, worksheet_id, worksheet_name, credentials, include_column_headers, display, backend)
#     147       url = f'https://docs.google.com/spreadsheets/d/{sheet_id}'
#     148     self._credentials = credentials
# --> 149     self._ensure_gspread_client()
#     150
#     151     self.sheet = self._load_or_create_sheet(url, title)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/sheets.py in _ensure_gspread_client(self)
#     217     global _gspread_client
#     218     if _gspread_client is None:
# --> 219       creds = InteractiveSheet.generate_creds(self._credentials)
# ...

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

type(whoami)
# Out:
# dict

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

print(whoami)
# Out:
# {'name': 'Arif Rahman Muda', 'age': 20, 'favFood': 'Carbs and Protein Foods'}

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

len(whoami)
# Out:
# 3

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

whoami["favDrink"]= "Coffee"
print(whoami)
# Out:
# {'name': 'Arif Rahman Muda', 'age': 20, 'favFood': 'Carbs and Protein Foods', 'favDrink': 'Coffee'}

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

type(whoami)
# Out:
# dict

# %%
whoami = {"name":"Arif Rahman Muda", "age": 20, "favFood": "Carbs and Protein Foods"}

print(whoami)
# Out:
# {'name': 'Arif Rahman Muda', 'age': 20, 'favFood': 'Carbs and Protein Foods'}
